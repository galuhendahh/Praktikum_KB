# %% [markdown]
# # POSTTEST_KB_3
# ##  Nama : Galun Endah Pambudi
# ##  Nim  : 2109106142
# ##  Kelas: Informatika C2'21
# ### Link Dataset: https://drive.google.com/drive/folders/1-8kyi2HRh7SEpHymBm6WhGR26I24SHzF

# %%
import pandas as pd
import os
# os.system("install matplotlib")
import matplotlib.pyplot as plt
import numpy as np

# mengambil dataset di file csv
df = pd.read_csv("product_reviews_dirty.csv");
df
# Out:
#        Unnamed: 0                                               text  rating  \
# 0               1             Barang sesuai pesanan dan cepat sampai       5
# 1               2                           Barang bagus harga murah       5
# 2               3    Paket rapi...mantap....cepat....sampe ke tujuan       5
# 3               4                         ya saya puas dgn barangnya       5
# 4               5                       Responya luar biasa b mantap       5
# ...           ...                                                ...     ...
# 40602       40889                gak bisa ditutup.. ukuran gak pas..       1
# 40603       40890  Penjual krg peduli dan brg jelek. Brg yg dikir...       1
# 40604       40891  pelayanan kurang sigap, berhari2 dr nanya baik...       1
# 40605       40892  barang yg dikirim tsk sesuai wrn, kl memang dr...       1
# 40606       40893  Pihak penjual memberikan respon yang buruk kep...       1
#
#           category                                       product_name  \
# 0      pertukangan  Staples Dekorasi Staples Kayu + Refill 8mm - S...
# 1      pertukangan  STAPLE GUN ATS 3 WAY TACKER - STAPLES JOK TEMB...
# 2      pertukangan  STAPLE GUN ATS 3 WAY TACKER - STAPLES JOK TEMB...
# 3      pertukangan  ALAT STAPLES TEMBAK &#40;AIR NAILER GUN&#41; O...
# 4      pertukangan  Isi Refill Staples Jok Kulit Motor / Staple Gu...
# ...            ...                                                ...
# 40602     olahraga  MINERAL WATER POT WATER PURIFIER 28 liter BIO ...
# 40603     olahraga  PANCI PRESTO IDEALIFE 7 LITER - IL 707 &#40; I...
# 40604     olahraga  EXCIDER BIKE 2 - sepeda fitnes magnetic lipat ...
# 40605     olahraga  TOTAL FITNES ALAT FITNESS SIT UP BENCH TOTAL &...
# 40606     olahraga  SIT UP BENCH HITAM 3 SISI - SITUP BANCH INCLIN...
#
#        product_id   sold  shop_id  \
# 0       418660637      1  1740837
# 1       416032545     11  1477109
# 2       416032545     11  1477109
# 3       102279869      5   771395
# 4       190679689    787   969999
# ...           ...    ...      ...
# 40602   144442054      2   648559
# 40603   313781913      1   648559
# 40604    71873370      1   648559
# 40605   201690705      2   648559
# 40606    78857201          648559
#
#                                              product_url
# 0      https://www.tokopedia.com/shakaonline87/staple...
# 1      https://www.tokopedia.com/juraganperkakas/stap...
# 2      https://www.tokopedia.com/juraganperkakas/stap...
# 3      https://www.tokopedia.com/kamarmesin/alat-stap...
# 4      https://www.tokopedia.com/mitrapersada/isi-ref...
# ...                                                  ...
# 40602  https://www.tokopedia.com/pusatdermawand/miner...
# 40603  https://www.tokopedia.com/pusatdermawand/panci...
# 40604  https://www.tokopedia.com/pusatdermawand/excid...
# 40605  https://www.tokopedia.com/pusatdermawand/total...
# 40606  https://www.tokopedia.com/pusatdermawand/sit-u...
#
# [40607 rows x 9 columns]

# %% [markdown]
# # GRAFIK BATANG
# ### Menampilkan 5 rating terbanyak berdasarkan kategori

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca dataset CSV ke dalam DataFrame
data = pd.read_csv("product_reviews_dirty.csv")

# Kelompokkan data berdasarkan jenis varietas dan hitung rata-rata harga
varietas_harga_rata = data.groupby('category')['rating'].mean()

# Urutkan hasil pengelompokan berdasarkan harga secara menurun
varietas_harga_rata_sorted = varietas_harga_rata.sort_values(ascending=False)

# Ambil 3 jenis varietas teratas
top_5_varieties = varietas_harga_rata_sorted.head(5)

# %%
top_5_varieties
# Out:
# category
# elektronik     4.757501
# fashion        4.674523
# pertukangan    4.643483
# olahraga       4.579740
# handphone      4.378422
# Name: rating, dtype: float64

# %%
# Buat diagram batang
plt.figure(figsize=(10, 6))
top_5_varieties.plot(kind='bar', color=['red','skyblue','green','yellow','purple'])
plt.title('Top 5 Rating Terbanyak')
plt.xlabel('Rating')
plt.ylabel('Kategori')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Kesimpulan Berdasarkan Grafik Batang
# ### Berdasarkan visualisasi diagram batang yang menggambarkan top 5 jenis anggur (varietas) termahal dari dataset winemag-data-130k-v2.csv, dapat disimpulkan hal-hal berikut:
#
# ### Varietas Termahal: Varietas anggur yang paling mahal dari dataset adalah "Ramisco" dengan harga rata-rata sebesar    495.000.000.
# ### Varietas Kedua: Setelah Ramisco, varietas anggur "Terrantez" menduduki peringkat kedua dalam hal harga rata-rata, dengan nilai sekitar 236.000.000.
# ### Varietas Ketiga: "Francisa" adalah varietas anggur termahal ketiga dengan harga rata-rata sekitar 160.000.000.
# ### Varietas Keempat: Di peringkat keempat, terdapat varietas anggur "Rosenmuskateller" dengan harga rata-rata sekitar 150.000.000.
# ### Varietas Kelima: Terakhir, varietas anggur "Malbec-Cabernet" menduduki peringkat kelima dengan harga rata-rata sekitar 113.333.333.
#
# ### Dengan demikian, visualisasi data ini memberikan informasi penting tentang jenis-jenis anggur yang memiliki harga rata-rata tertinggi dalam dataset, dengan Ramisco menjadi yang paling mahal di antara semuanya. Informasi ini dapat berguna dalam pengambilan keputusan terkait dengan pembelian atau penjualan anggur, serta dalam pemahaman lebih lanjut tentang tren harga varietas anggur tertentu dalam industri anggur.

# %% [markdown]
# # GRAFIK HISTOGRAM
# ### Menampilkan jumlah orang yang memberikan penilaian berdasarkan points

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca dataset CSV ke dalam DataFrame
data = pd.read_csv('product_reviews_dirty.csv')

# Plot histogram untuk distribusi poin yang diberikan oleh taster
plt.figure(figsize=(10, 6))
plt.hist(data['rating'], bins=20, edgecolor='k', alpha=0.7)
plt.xlabel('Poin')
plt.ylabel('Jumlah Penilaian')
plt.title('Distribusi Rating yang Diberikan oleh Taster')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # GRAFIK PIE CHART
# ### Menampilkan 10 wilayah pendistribusi wine berdasarkan Provinsi

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca dataset CSV ke dalam DataFrame
data = pd.read_csv('product_reviews_dirty.csv')

# Hitung jumlah anggur di setiap region_1
jumlah_per_region = data['sold'].value_counts()

# Batasi jumlah region yang akan ditampilkan agar grafik tidak terlalu padat
n = 10  # Contoh: Tampilkan 10 region teratas
jumlah_per_region = jumlah_per_region.head(n)

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(jumlah_per_region, labels=jumlah_per_region.index, autopct='%1.1f%%', startangle=180)
plt.title('10 Wilayah Pendistribusi rating terbanyak berdarkan jumlah sold')
plt.xlabel('Sold')
plt.show()

# %% [markdown]
# # GRAFIK HEATMAP
#
# ## Menghitung matriks korelasi dari atribut numerik points dan price

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Baca dataset CSV ke dalam DataFrame
data = pd.read_csv('product_reviews_dirty.csv')

# Pilih subset fitur yang ingin Anda analisis
subset_data = data[['rating', 'sold']]


# Hitung matriks korelasi
correlation_matrix = subset_data.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.xlabel('Poin (Points)')
plt.ylabel('Harga (Price)')
plt.title('Heatmap Hubungan antara rating dan jumlah sold')
plt.show()
# Out:
# C:\Users\fathu\AppData\Local\Temp\ipykernel_26040\2197892713.py:13: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = subset_data.corr()
